# %%
reset()

# Define matrix multiplication for form-valued matrices
def matmul(A,B):
    C1=A[0,0]*B[0,0]+A[0,1]*B[1,0]
    C2=A[0,0]*B[0,1]+A[0,1]*B[1,1]
    C3=A[1,0]*B[0,0]+A[1,1]*B[1,0]
    C4=A[1,0]*B[0,1]+A[1,1]*B[1,1]
    C=Matrix([[C1,C2],[C3,C4]])
    return C

# Define forms
E.<l,n,m,mbar,dl,dn,dm,dmbar,Gamma0,Gamma1,Gamma2,dGamma0,dGamma1,dGamma2,Gamma0conj,Gamma1conj,Gamma2conj,R0,R1,R2> = ExteriorAlgebra(SR)

# Define variables
var('alpha,beta,epsilon,gamma,kappa,mu,nu,pi,rho,sigma,tau',domain='complex')
var('lambdaa',latex_name=r"\lambda",domain='complex')
var('Phi00,Phi01,Phi02,Phi10,Phi11,Phi12,Phi20,Phi21,Phi22,Lambda',domain='complex')
var('Psi0,Psi1,Psi2,Psi3,Psi4',domain='complex')

# Define Gammas and their conjugates:
Gamma0=gamma*l+epsilon*n-alpha*m-beta*mbar
Gamma1=-tau*l-kappa*n+rho*m+sigma*mbar
Gamma2=nu*l+pi*n-lambdaa*m-mu*mbar

Gamma0conj=conjugate(gamma)*l+conjugate(epsilon)*n-conjugate(alpha)*mbar-conjugate(beta)*m
Gamma1conj=-conjugate(tau)*l-conjugate(kappa)*n+conjugate(rho)*mbar+conjugate(sigma)*m
Gamma2conj=conjugate(nu)*l+conjugate(pi)*n-conjugate(lambdaa)*mbar-conjugate(mu)*m

#Define Rs
R0=(-Psi2-Phi11+Lambda)*l*n+Psi3*l*m+Phi12*l*mbar-Phi10*n*m-Psi1*n*mbar+(Psi2-Phi11-Lambda)*m*mbar
R1=(Psi1+Phi01)*l*n-(Psi2+2*Lambda)*l*m-Phi02*l*mbar+Phi00*n*m+Psi0*n*mbar+(-Psi1+Phi01)*m*mbar
R2=-(Psi3+Phi21)*l*n+Psi4*l*m+Phi22*l*mbar-Phi20*n*m-(Psi2+2*Lambda)*n*mbar+(Psi3-Phi21)*m*mbar

# Define the sigma, Gamma, R matrices
sigmas=Matrix([[l,m],[mbar,n]])
dsigmas=Matrix([[dl,dm],[dmbar,dn]])
sigmasconj=Matrix([[l,mbar],[m,n]])

gammas=Matrix([[Gamma0,Gamma1],[Gamma2,-Gamma0]])
gammashermitianconj=Matrix([[Gamma0conj,Gamma2conj],[Gamma1conj,-Gamma0conj]])

Rs=Matrix([[R0,R1],[R2,-R0]])

# Calculate the equations
# Connection
show("Connection:")

NPmatrix1=dsigmas-matmul(gammas,sigmas)+matmul(sigmas,gammashermitianconj)

show("#######################")
show(NPmatrix1[0,0])
show("#######################")
show(NPmatrix1[0,1])
show("#######################")
show(NPmatrix1[1,0])
show("#######################")
show(NPmatrix1[1,1])
show("#######################")

# Set dl as dl1, dn as dn1, etc. for substitutions into other equations
dl1=-NPmatrix1[0,0]+dl
dm1=-NPmatrix1[0,1]+dm
dmbar1=-NPmatrix1[1,0]+dmbar
dn1=-NPmatrix1[1,1]+dn

show("-------------------------------------------------------------------------")
#Curvature
show("Curvature:")

dGamma0=gamma*dl1+epsilon*dn1-alpha*dm1-beta*dmbar1
dGamma1=-tau*dl1-kappa*dn1+rho*dm1+sigma*dmbar1
dGamma2=nu*dl1+pi*dn1-lambdaa*dm1-mu*dmbar1

dgammas=Matrix([[dGamma0,dGamma1],[dGamma2,-dGamma0]])

NPmatrix2=Rs-dgammas+matmul(gammas,gammas)

show("#######################")
show(NPmatrix2[0,0])
show("#######################")
show(NPmatrix2[0,1])
show("#######################")
show(NPmatrix2[1,0])
show("#######################")
show(NPmatrix2[1,1])
show("#######################")

show("-------------------------------------------------------------------------")
# Bianchi
show("Bianchi:")

dR0=(Lambda*n+Psi3*m+mbar*Phi12-n*Phi11-n*Psi2)*dl1+(Lambda*l-l*Phi11-l*Psi2-m*Phi10-mbar*Psi1)*dn1-(Lambda*mbar-l*Psi3+mbar*Phi11-mbar*Psi2+n*Phi10)*dm1-(Lambda*m-l*Phi12+m*Phi11-m*Psi2+n*Psi1)*dmbar1
dR1=-(2*Lambda*m+Psi2*m+mbar*Phi02-n*Phi01-n*Psi1)*dl1+(Psi1*l+l*Phi01-l*Psi2+m*Phi00+mbar*Psi0)*dn1-(2*Lambda*l+l*Psi2-mbar*Phi01+mbar*Psi1-n*Phi00)*dm1-(Phi02*l-m*Phi01+m*Psi1-Psi0*n)*dmbar1
dR2=(Psi4*m+Phi22*mbar-n*Phi21-n*Psi3)*dl1-(2*mbar*Lambda+l*Phi21+l*Psi3+Phi20*m+mbar*Psi2)*dn1+(Psi4*l-mbar*Phi21+mbar*Psi3-Phi20*n)*dm1-(2*n*Lambda-Phi22*l+m*Phi21-m*Psi3+n*Psi2)*dmbar1

dRs=Matrix([[dR0,dR1],[dR2,-dR0]])

NPmatrix3=dRs+matmul(Rs,gammas)-matmul(gammas,Rs)

show("#######################")
show(NPmatrix3[0,0])
show("#######################")
show(NPmatrix3[0,1])
show("#######################")
show(NPmatrix3[1,0])
show("#######################")
show(NPmatrix3[1,1])
show("#######################")
# Out:
# 'Connection:'
# '#######################'
# (epsilon + conjugate(epsilon))*l*n + (-alpha - conjugate(beta) + conjugate(tau))*l*m + (-beta + tau - conjugate(alpha))*l*mbar + conjugate(kappa)*n*m + kappa*n*mbar + (-rho + conjugate(rho))*m*mbar + dl
# '#######################'
# (tau + conjugate(pi))*l*n + (-gamma + conjugate(gamma) - conjugate(mu))*l*m - conjugate(lambdaa)*l*mbar + (-epsilon + rho + conjugate(epsilon))*n*m + sigma*n*mbar + (-beta + conjugate(alpha))*m*mbar + dm
# '#######################'
# (pi + conjugate(tau))*l*n - lambdaa*l*m + (gamma - mu - conjugate(gamma))*l*mbar + conjugate(sigma)*n*m + (epsilon - conjugate(epsilon) + conjugate(rho))*n*mbar + (-alpha + conjugate(beta))*m*mbar + dmbar
# '#######################'
# (gamma + conjugate(gamma))*l*n - nu*l*m - conjugate(nu)*l*mbar + (alpha - pi + conjugate(beta))*n*m + (beta + conjugate(alpha) - conjugate(pi))*n*mbar + (-mu + conjugate(mu))*m*mbar + dn
# '#######################'
# '-------------------------------------------------------------------------'
# 'Curvature:'
# '#######################'
# (epsilon*(gamma + conjugate(gamma)) + (epsilon + conjugate(epsilon))*gamma + kappa*nu - beta*(pi + conjugate(tau)) - alpha*(tau + conjugate(pi)) - pi*tau + Lambda - Phi11 - Psi2)*l*n + (alpha*(gamma - conjugate(gamma) + conjugate(mu)) - (alpha + conjugate(beta) - conjugate(tau))*gamma + beta*lambdaa - epsilon*nu - nu*rho + lambdaa*tau + Psi3)*l*m + (-beta*(gamma - mu - conjugate(gamma)) - (beta - tau + conjugate(alpha))*gamma - nu*sigma + mu*tau + alpha*conjugate(lambdaa) - epsilon*conjugate(nu) + Phi12)*l*mbar + (alpha*(epsilon - rho - conjugate(epsilon)) + (alpha - pi + conjugate(beta))*epsilon + kappa*lambdaa - pi*rho + gamma*conjugate(kappa) - beta*conjugate(sigma) - Phi10)*n*m + (-beta*(epsilon - conjugate(epsilon) + conjugate(rho)) + (beta + conjugate(alpha) - conjugate(pi))*epsilon + gamma*kappa + kappa*mu - alpha*sigma - pi*sigma - Psi1)*n*mbar + (alpha*(beta - conjugate(alpha)) + (alpha - conjugate(beta))*beta - epsilon*(mu - conjugate(mu)) - gamma*(rho - conjugate(rho)) - mu*rho + lambdaa*sigma - Lambda - Phi11 + Psi2)*m*mbar
# '#######################'
# (-(gamma + conjugate(gamma))*kappa - 2*gamma*kappa + (pi + conjugate(tau))*sigma + rho*(tau + conjugate(pi)) - (epsilon + conjugate(epsilon))*tau + 2*epsilon*tau + Phi01 + Psi1)*l*n + (kappa*nu - (gamma - conjugate(gamma) + conjugate(mu))*rho + 2*gamma*rho - lambdaa*sigma + (alpha + conjugate(beta) - conjugate(tau))*tau - 2*alpha*tau - 2*Lambda - Psi2)*l*m + ((gamma - mu - conjugate(gamma))*sigma + 2*gamma*sigma + (beta - tau + conjugate(alpha))*tau - 2*beta*tau - rho*conjugate(lambdaa) + kappa*conjugate(nu) - Phi02)*l*mbar + (-(alpha - pi + conjugate(beta))*kappa - 2*alpha*kappa - (epsilon - rho - conjugate(epsilon))*rho + 2*epsilon*rho - tau*conjugate(kappa) + sigma*conjugate(sigma) + Phi00)*n*m + (-(beta + conjugate(alpha) - conjugate(pi))*kappa - 2*beta*kappa + (epsilon - conjugate(epsilon) + conjugate(rho))*sigma + 2*epsilon*sigma + rho*sigma - kappa*tau + Psi0)*n*mbar + (kappa*(mu - conjugate(mu)) - (beta - conjugate(alpha))*rho + 2*beta*rho - (alpha - conjugate(beta))*sigma - 2*alpha*sigma + (rho - conjugate(rho))*tau + Phi01 - Psi1)*m*mbar
# '#######################'
# ((epsilon + conjugate(epsilon))*nu + 2*epsilon*nu - mu*(pi + conjugate(tau)) + (gamma + conjugate(gamma))*pi - 2*gamma*pi - lambdaa*(tau + conjugate(pi)) - Phi21 - Psi3)*l*n + ((gamma - conjugate(gamma) + conjugate(mu))*lambdaa + 2*gamma*lambdaa + lambdaa*mu - (alpha + conjugate(beta) - conjugate(tau))*nu - 2*alpha*nu - nu*pi + Psi4)*l*m + (-(gamma - mu - conjugate(gamma))*mu + 2*gamma*mu - (beta - tau + conjugate(alpha))*nu - 2*beta*nu + lambdaa*conjugate(lambdaa) - pi*conjugate(nu) + Phi22)*l*mbar + ((epsilon - rho - conjugate(epsilon))*lambdaa + 2*epsilon*lambdaa + (alpha - pi + conjugate(beta))*pi - 2*alpha*pi + nu*conjugate(kappa) - mu*conjugate(sigma) - Phi20)*n*m + (-(epsilon - conjugate(epsilon) + conjugate(rho))*mu + 2*epsilon*mu + kappa*nu + (beta + conjugate(alpha) - conjugate(pi))*pi - 2*beta*pi - lambdaa*sigma - 2*Lambda - Psi2)*n*mbar + ((beta - conjugate(alpha))*lambdaa + 2*beta*lambdaa + (alpha - conjugate(beta))*mu - 2*alpha*mu - (mu - conjugate(mu))*pi - nu*(rho - conjugate(rho)) - Phi21 + Psi3)*m*mbar
# '#######################'
# (-epsilon*(gamma + conjugate(gamma)) - (epsilon + conjugate(epsilon))*gamma - kappa*nu + beta*(pi + conjugate(tau)) + alpha*(tau + conjugate(pi)) + pi*tau - Lambda + Phi11 + Psi2)*l*n + (-alpha*(gamma - conjugate(gamma) + conjugate(mu)) + (alpha + conjugate(beta) - conjugate(tau))*gamma - beta*lambdaa + epsilon*nu + nu*rho - lambdaa*tau - Psi3)*l*m + (beta*(gamma - mu - conjugate(gamma)) + (beta - tau + conjugate(alpha))*gamma + nu*sigma - mu*tau - alpha*conjugate(lambdaa) + epsilon*conjugate(nu) - Phi12)*l*mbar + (-alpha*(epsilon - rho - conjugate(epsilon)) - (alpha - pi + conjugate(beta))*epsilon - kappa*lambdaa + pi*rho - gamma*conjugate(kappa) + beta*conjugate(sigma) + Phi10)*n*m + (beta*(epsilon - conjugate(epsilon) + conjugate(rho)) - (beta + conjugate(alpha) - conjugate(pi))*epsilon - gamma*kappa - kappa*mu + alpha*sigma + pi*sigma + Psi1)*n*mbar + (-alpha*(beta - conjugate(alpha)) - (alpha - conjugate(beta))*beta + epsilon*(mu - conjugate(mu)) + gamma*(rho - conjugate(rho)) + mu*rho - lambdaa*sigma + Lambda + Phi11 - Psi2)*m*mbar
# '#######################'
# '-------------------------------------------------------------------------'
# 'Bianchi:'
# '#######################'
# (-(Lambda - Phi11 - Psi2)*(alpha - pi + conjugate(beta)) - (Lambda - Phi11 - Psi2)*(alpha + conjugate(beta) - conjugate(tau)) + Psi3*(epsilon - rho - conjugate(epsilon)) - Psi3*(epsilon + conjugate(epsilon)) + Phi10*(gamma + conjugate(gamma)) + Phi10*(gamma - conjugate(gamma) + conjugate(mu)) - Psi4*kappa - (Phi01 + Psi1)*lambdaa + Psi1*lambdaa + Phi00*nu + (Lambda + Phi11 - Psi2)*(pi + conjugate(tau)) + (2*Lambda + Psi2)*pi + (Phi21 + Psi3)*rho - Phi20*tau - Phi12*conjugate(sigma))*l*n*m + (-(Lambda - Phi11 - Psi2)*(beta - tau + conjugate(alpha)) - (Lambda - Phi11 - Psi2)*(beta + conjugate(alpha) - conjugate(pi)) - Phi12*(epsilon + conjugate(epsilon)) - Phi12*(epsilon - conjugate(epsilon) + conjugate(rho)) - Psi1*(gamma - mu - conjugate(gamma)) + Psi1*(gamma + conjugate(gamma)) - Phi22*kappa - (Phi01 + Psi1)*mu + Psi0*nu + Phi02*pi + (Phi21 + Psi3)*sigma - Psi3*sigma + (Lambda + Phi11 - Psi2)*(tau + conjugate(pi)) - (2*Lambda + Psi2)*tau + Phi10*conjugate(lambdaa))*l*n*mbar + (Phi12*(alpha + conjugate(beta) - conjugate(tau)) + Phi12*(alpha - conjugate(beta)) - Psi3*(beta - tau + conjugate(alpha)) + Psi3*(beta - conjugate(alpha)) - (Lambda + Phi11 - Psi2)*(gamma - mu - conjugate(gamma)) - (Lambda + Phi11 - Psi2)*(gamma - conjugate(gamma) + conjugate(mu)) - Phi02*lambdaa + (Lambda - Phi11 - Psi2)*(mu - conjugate(mu)) + (2*Lambda + Psi2)*mu + (Phi01 - Psi1)*nu - Psi1*nu + Phi22*rho - Psi4*sigma - (Phi21 - Psi3)*tau + Phi10*conjugate(nu))*l*m*mbar + (Psi1*(alpha - pi + conjugate(beta)) - Psi1*(alpha - conjugate(beta)) - Phi10*(beta + conjugate(alpha) - conjugate(pi)) - Phi10*(beta - conjugate(alpha)) - (Lambda + Phi11 - Psi2)*(epsilon - rho - conjugate(epsilon)) - (Lambda + Phi11 - Psi2)*(epsilon - conjugate(epsilon) + conjugate(rho)) - (Phi21 - Psi3)*kappa + Psi3*kappa + Psi0*lambdaa - Phi00*mu + (Phi01 - Psi1)*pi + (Lambda - Phi11 - Psi2)*(rho - conjugate(rho)) - (2*Lambda + Psi2)*rho + Phi20*sigma - Phi12*conjugate(kappa))*n*m*mbar
# '#######################'
# (-(Phi01 + Psi1 - Psi2)*(alpha - pi + conjugate(beta)) - (Phi01 + Psi1)*(alpha + conjugate(beta) - conjugate(tau)) + 2*(Phi01 + Psi1)*alpha - (2*Lambda + Psi2)*(epsilon - rho - conjugate(epsilon)) + (2*Lambda + Psi2)*(epsilon + conjugate(epsilon)) - 2*(2*Lambda + Psi2)*epsilon - Phi00*(gamma + conjugate(gamma)) - Phi00*(gamma - conjugate(gamma) + conjugate(mu)) - 2*Phi00*gamma + 2*Psi3*kappa - Psi0*lambdaa - (Phi01 - Psi1)*(pi + conjugate(tau)) + 2*(Lambda - Phi11 - Psi2)*rho + 2*Phi10*tau + Phi02*conjugate(sigma))*l*n*m + (-(Phi01 + Psi1)*(beta - tau + conjugate(alpha)) - (Phi01 + Psi1 - Psi2)*(beta + conjugate(alpha) - conjugate(pi)) + 2*(Phi01 + Psi1)*beta + Phi02*(epsilon + conjugate(epsilon)) + Phi02*(epsilon - conjugate(epsilon) + conjugate(rho)) - 2*Phi02*epsilon + Psi0*(gamma - mu - conjugate(gamma)) - Psi0*(gamma + conjugate(gamma)) - 2*Psi0*gamma + 2*Phi12*kappa + (2*Lambda + Psi2)*sigma + 2*(Lambda - Phi11 - Psi2)*sigma - (Phi01 - Psi1)*(tau + conjugate(pi)) + 2*Psi1*tau - Phi00*conjugate(lambdaa))*l*n*mbar + (-Phi02*(alpha + conjugate(beta) - conjugate(tau)) - Phi02*(alpha - conjugate(beta)) + 2*Phi02*alpha + (2*Lambda + Psi2)*(beta - tau + conjugate(alpha)) - (2*Lambda + Psi2)*(beta - conjugate(alpha)) - 2*(2*Lambda + Psi2)*beta + (Phi01 - Psi1)*(gamma - mu - conjugate(gamma)) + (Phi01 - Psi1)*(gamma - conjugate(gamma) + conjugate(mu)) - 2*(Phi01 - Psi1)*gamma + (Phi01 + Psi1 - Psi2)*(mu - conjugate(mu)) + Psi0*nu - 2*Phi12*rho + 2*Psi3*sigma + 2*(Lambda + Phi11 - Psi2)*tau - Phi00*conjugate(nu))*l*m*mbar + (-Psi0*(alpha - pi + conjugate(beta)) + Psi0*(alpha - conjugate(beta)) - 2*Psi0*alpha + Phi00*(beta + conjugate(alpha) - conjugate(pi)) + Phi00*(beta - conjugate(alpha)) + 2*Phi00*beta + (Phi01 - Psi1)*(epsilon - rho - conjugate(epsilon)) + (Phi01 - Psi1)*(epsilon - conjugate(epsilon) + conjugate(rho)) - 2*(Phi01 - Psi1)*epsilon - (2*Lambda + Psi2)*kappa + 2*(Lambda + Phi11 - Psi2)*kappa + (Phi01 + Psi1)*(rho - conjugate(rho)) + 2*Psi1*rho - 2*Phi10*sigma + Phi02*conjugate(kappa))*n*m*mbar
# '#######################'
# ((Phi21 + Psi3)*(alpha - pi + conjugate(beta)) + (Phi21 + Psi3)*(alpha + conjugate(beta) - conjugate(tau)) + 2*(Phi21 + Psi3)*alpha + Psi4*(epsilon - rho - conjugate(epsilon)) - Psi4*(epsilon + conjugate(epsilon)) - 2*Psi4*epsilon + Phi20*(gamma + conjugate(gamma)) + Phi20*(gamma - conjugate(gamma) + conjugate(mu)) - 2*Phi20*gamma + (2*Lambda + Psi2)*lambdaa + 2*(Lambda - Phi11 - Psi2)*lambdaa + 2*Phi10*nu + (Phi21 - Psi3)*(pi + conjugate(tau)) + 2*Psi3*pi - Phi22*conjugate(sigma))*l*n*m + ((Phi21 + Psi3)*(beta - tau + conjugate(alpha)) + (Phi21 + Psi3)*(beta + conjugate(alpha) - conjugate(pi)) + 2*(Phi21 + Psi3)*beta - Phi22*(epsilon + conjugate(epsilon)) - Phi22*(epsilon - conjugate(epsilon) + conjugate(rho)) - 2*Phi22*epsilon - (2*Lambda + Psi2)*(gamma - mu - conjugate(gamma)) + (2*Lambda + Psi2)*(gamma + conjugate(gamma)) - 2*(2*Lambda + Psi2)*gamma + 2*(Lambda - Phi11 - Psi2)*mu + 2*Psi1*nu + 2*Phi12*pi - Psi4*sigma + (Phi21 - Psi3)*(tau + conjugate(pi)) + Phi20*conjugate(lambdaa))*l*n*mbar + (Phi22*(alpha + conjugate(beta) - conjugate(tau)) + Phi22*(alpha - conjugate(beta)) + 2*Phi22*alpha - Psi4*(beta - tau + conjugate(alpha)) + Psi4*(beta - conjugate(alpha)) - 2*Psi4*beta - (Phi21 - Psi3)*(gamma - mu - conjugate(gamma)) - (Phi21 - Psi3)*(gamma - conjugate(gamma) + conjugate(mu)) - 2*(Phi21 - Psi3)*gamma - 2*Phi12*lambdaa - (Phi21 + Psi3)*(mu - conjugate(mu)) + 2*Psi3*mu - (2*Lambda + Psi2)*nu + 2*(Lambda + Phi11 - Psi2)*nu + Phi20*conjugate(nu))*l*m*mbar + ((2*Lambda + Psi2)*(alpha - pi + conjugate(beta)) - (2*Lambda + Psi2)*(alpha - conjugate(beta)) - 2*(2*Lambda + Psi2)*alpha - Phi20*(beta + conjugate(alpha) - conjugate(pi)) - Phi20*(beta - conjugate(alpha)) + 2*Phi20*beta - (Phi21 - Psi3)*(epsilon - rho - conjugate(epsilon)) - (Phi21 - Psi3)*(epsilon - conjugate(epsilon) + conjugate(rho)) - 2*(Phi21 - Psi3)*epsilon + Psi4*kappa + 2*Psi1*lambdaa - 2*Phi10*mu + 2*(Lambda + Phi11 - Psi2)*pi - (Phi21 + Psi3)*(rho - conjugate(rho)) - Phi22*conjugate(kappa))*n*m*mbar
# '#######################'
# ((Lambda - Phi11 - Psi2)*(alpha - pi + conjugate(beta)) + (Lambda - Phi11 - Psi2)*(alpha + conjugate(beta) - conjugate(tau)) - Psi3*(epsilon - rho - conjugate(epsilon)) + Psi3*(epsilon + conjugate(epsilon)) - Phi10*(gamma + conjugate(gamma)) - Phi10*(gamma - conjugate(gamma) + conjugate(mu)) + Psi4*kappa + (Phi01 + Psi1)*lambdaa - Psi1*lambdaa - Phi00*nu - (Lambda + Phi11 - Psi2)*(pi + conjugate(tau)) - (2*Lambda + Psi2)*pi - (Phi21 + Psi3)*rho + Phi20*tau + Phi12*conjugate(sigma))*l*n*m + ((Lambda - Phi11 - Psi2)*(beta - tau + conjugate(alpha)) + (Lambda - Phi11 - Psi2)*(beta + conjugate(alpha) - conjugate(pi)) + Phi12*(epsilon + conjugate(epsilon)) + Phi12*(epsilon - conjugate(epsilon) + conjugate(rho)) + Psi1*(gamma - mu - conjugate(gamma)) - Psi1*(gamma + conjugate(gamma)) + Phi22*kappa + (Phi01 + Psi1)*mu - Psi0*nu - Phi02*pi - (Phi21 + Psi3)*sigma + Psi3*sigma - (Lambda + Phi11 - Psi2)*(tau + conjugate(pi)) + (2*Lambda + Psi2)*tau - Phi10*conjugate(lambdaa))*l*n*mbar + (-Phi12*(alpha + conjugate(beta) - conjugate(tau)) - Phi12*(alpha - conjugate(beta)) + Psi3*(beta - tau + conjugate(alpha)) - Psi3*(beta - conjugate(alpha)) + (Lambda + Phi11 - Psi2)*(gamma - mu - conjugate(gamma)) + (Lambda + Phi11 - Psi2)*(gamma - conjugate(gamma) + conjugate(mu)) + Phi02*lambdaa - (Lambda - Phi11 - Psi2)*(mu - conjugate(mu)) - (2*Lambda + Psi2)*mu - (Phi01 - Psi1)*nu + Psi1*nu - Phi22*rho + Psi4*sigma + (Phi21 - Psi3)*tau - Phi10*conjugate(nu))*l*m*mbar + (-Psi1*(alpha - pi + conjugate(beta)) + Psi1*(alpha - conjugate(beta)) + Phi10*(beta + conjugate(alpha) - conjugate(pi)) + Phi10*(beta - conjugate(alpha)) + (Lambda + Phi11 - Psi2)*(epsilon - rho - conjugate(epsilon)) + (Lambda + Phi11 - Psi2)*(epsilon - conjugate(epsilon) + conjugate(rho)) + (Phi21 - Psi3)*kappa - Psi3*kappa - Psi0*lambdaa + Phi00*mu - (Phi01 - Psi1)*pi - (Lambda - Phi11 - Psi2)*(rho - conjugate(rho)) + (2*Lambda + Psi2)*rho - Phi20*sigma + Phi12*conjugate(kappa))*n*m*mbar
# '#######################'
